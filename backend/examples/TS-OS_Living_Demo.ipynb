# %% [markdown]
# # TS-OS Living Demo
#
# This notebook demonstrates graph evolution, autonomous modes, and self-improvement flow.

# %%
from BoggersTheAI import BoggersRuntime

rt = BoggersRuntime()
print(rt.get_status())

# %%
queries = [
    "What is TS-OS?",
    "How does wave propagation work?",
    "Show me the current graph reasoning state.",
]
for q in queries:
    r = rt.ask(q)
    print(f"Q: {q}")
    print(f"A: {r.answer[:180]}\n")

print("Status after graph evolution:", rt.get_status())

# %%
# Manual self-improvement trigger (safe if safety_dry_run is enabled)
stats = rt.trigger_self_improvement()
stats

# %% [markdown]
# ## TUI Screenshot Placeholder
#
# Add a screenshot of the TUI here after running:
#
# ```bash
# boggers
# ```
#
# or via runtime:
#
# ```python
# rt.run_tui()
# ```
